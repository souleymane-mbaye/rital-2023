# %% [markdown]
# # Recherche d'information : librairie PyTerrier
#
# Dans cette partie, nous nous intéressons à la librairie [PyTerrier](https://pyterrier.readthedocs.io/en/latest/#) qui permet de mettre en place diverses briques d'un moteur de recherche.
# PyTerrier est basée sur [Terrier](http://terrier.org/) qui est un moteur de recherche développé en Java.
#
# Nous allons voir :
# *   l'installation et la configuration
# *   l'indexation d'une collection
# *   l'accès à l'index
# *   l'évaluation d'un moteur de recherche

# %% [markdown]
# ## Installation ete configuration
#
# Après l'installation de la librairie, il est nécessaire d'initialiser PyTerrier pour importer les fichiers jar et démarrer la machine virtuelle associée;

# %%
# !pip install python-terrier

import pyterrier as pt
if not pt.started():
  pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting python-terrier
#   Downloading python-terrier-0.9.2.tar.gz (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 34.1 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from python-terrier) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (from python-terrier) (1.5.3)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from python-terrier) (4.64.1)
# Collecting pyjnius>=1.4.2
#   Downloading pyjnius-1.4.2-cp39-cp39-macosx_10_9_x86_64.whl (276 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.3/276.3 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting matchpy
#   Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 612.1 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from python-terrier) (1.2.1)
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting chest
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from python-terrier) (1.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from python-terrier) (2.27.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/site-packages (from python-terrier) (1.2.0)
# Collecting nptyping==1.4.4
#   Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Collecting more_itertools
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting ir_datasets>=0.3.2
#   Downloading ir_datasets-0.5.4-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 kB 1.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from python-terrier) (3.1.1)
# Collecting statsmodels
#   Downloading statsmodels-0.13.5-cp39-cp39-macosx_10_9_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 107.4 kB/s eta 0:00:0000:0100:03
# Collecting ir_measures>=0.3.1
#   Downloading ir_measures-0.3.1.tar.gz (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 418.5 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 549.6 kB/s eta 0:00:00a 0:00:01
# Collecting pytrec_eval_terrier>=0.5.3
#   Downloading pytrec_eval_terrier-0.5.5-cp39-cp39-macosx_10_15_x86_64.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 716.6 kB/s eta 0:00:00 0:00:01
# Collecting typish>=1.7.0
#   Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 937.8 kB/s eta 0:00:00 0:00:01
# Collecting lz4>=3.1.1
#   Downloading lz4-4.3.2-cp39-cp39-macosx_10_9_x86_64.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 15.5 kB/s eta 0:00:00a 0:00:02
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.9/site-packages (from ir_datasets>=0.3.2->python-terrier) (6.0)
# Collecting trec-car-tools>=2.5.4
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting ijson>=3.1.3
#   Downloading ijson-3.2.0.post0-cp39-cp39-macosx_10_9_x86_64.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 292.3 kB/s eta 0:00:00a 0:00:01
# Collecting pyautocorpus>=0.1.1
#   Downloading pyautocorpus-0.1.9-cp39-cp39-macosx_10_15_x86_64.whl (24 kB)
# Collecting unlzw3>=0.2.1
#   Downloading unlzw3-0.2.2-py3-none-any.whl (6.1 kB)
# Collecting warc3-wet-clueweb09>=0.2.5
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting zlib-state>=0.1.3
#   Downloading zlib-state-0.1.5.tar.gz (9.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lxml>=4.5.2
#   Downloading lxml-4.9.2-cp39-cp39-macosx_10_15_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 93.4 kB/s eta 0:00:0000:0100:02m
# Collecting warc3-wet>=0.2.3
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Collecting beautifulsoup4>=4.4.1
#   Downloading beautifulsoup4-4.12.0-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 499.6 kB/s eta 0:00:00a 0:00:01
# Collecting cwl-eval>=1.0.10
#   Downloading cwl-eval-1.0.12.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.9/site-packages (from pyjnius>=1.4.2->python-terrier) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->python-terrier) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/site-packages (from requests->python-terrier) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->python-terrier) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->python-terrier) (2021.10.8)
# Collecting heapdict
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.15.0-cp39-cp39-macosx_10_9_x86_64.whl (35 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/site-packages (from jinja2->python-terrier) (2.1.1)
# Collecting multiset<3.0,>=2.0
#   Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/site-packages (from pandas->python-terrier) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/site-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn->python-terrier) (3.1.0)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 617.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/site-packages (from statsmodels->python-terrier) (21.3)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4-py3-none-any.whl (37 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.9/site-packages (from packaging>=21.3->statsmodels->python-terrier) (2.4.7)
# Collecting cbor>=1.0.0
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: python-terrier, ir_measures, chest, wget, cwl-eval, warc3-wet-clueweb09, zlib-state, cbor
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.9.2-py3-none-any.whl size=112258 sha256=c6a19bc36ae19af765edad1b8e8b3366d5001675c4570d6a7db0ec111ced2019
#   Stored in directory: /Users/souleymbaye/Library/Caches/pip/wheels/0c/4d/40/9d00263171f82fe37049a60e70a88279ce025c0229110153d4
#   Building wheel for ir_measures (setup.py) ... done
#   Created wheel for ir_measures: filename=ir_measures-0.3.1-py3-none-any.whl size=60165 sha256=6cf2cd608a78934934f3ab4c3a9724b16f5c6f8f8d0d6e13f324aa53f81eb53a
#   Stored in directory: /Users/souleymbaye/Library/Caches/pip/wheels/00/fa/7d/0ba22fce7d11d69df68c31b7c247fbbb28fe2d4c610f8c653f
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7611 sha256=4996e8472ae778e225def9c8559ca1ade8eecaed2d353a4ca9e427393fc642f2
#   Stored in directory: /Users/souleymbaye/Library/Caches/pip/wheels/ce/05/8e/2ecd3728ed5d938ee57161c8acf2ee74f55f894964bb3d31ef
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=7ea96a0f416d5047cbe89cd7addd67c8c71e99df05e98e4b45a7369f42282783
#   Stored in directory: /Users/souleymbaye/Library/Caches/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.12-py3-none-any.whl size=38067 sha256=71b0343373e79a6a69741e8162743c5a9160eac67b4eb8ebc3dd20fcf3c21949
#   Stored in directory: /Users/souleymbaye/Library/Caches/pip/wheels/0e/52/dc/9d448ff093ccae9b248a41b265d31e2c930eea2d0e84aa29e0
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18918 sha256=5994fa9386394f87d629b51533debaf0aa394cf0560592708c44b4b760b5cec3
#   Stored in directory: /Users/souleymbaye/Library/Caches/pip/wheels/7f/22/ed/a11944d7fdf4e94c4206a3f760d385122a4d34d8acc12f71a3
#   Building wheel for zlib-state (setup.py) ... done
#   Created wheel for zlib-state: filename=zlib_state-0.1.5-cp39-cp39-macosx_12_0_x86_64.whl size=9561 sha256=5680f4615280f635927177a493d70bb8fba03546f087b4809785a80f49fae5e7
#   Stored in directory: /Users/souleymbaye/Library/Caches/pip/wheels/ae/72/87/265f3d5c5e75394f4ab54205ba8e0e3f61ba02dfaf061baede
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp39-cp39-macosx_12_0_x86_64.whl size=20814 sha256=5c524617a070b376c4246a3c79844ec49b29e7a4f65062f4509c94c7c513ee2d
#   Stored in directory: /Users/souleymbaye/Library/Caches/pip/wheels/ec/10/03/a281e0682ddd4b310431fb25d1a4f53987105267cf46c417f3
# Successfully built python-terrier ir_measures chest wget cwl-eval warc3-wet-clueweb09 zlib-state cbor
# Installing collected packages: wget, warc3-wet-clueweb09, warc3-wet, typish, multiset, ijson, heapdict, cbor, zlib-state, wrapt, unlzw3, trec-car-tools, soupsieve, pytrec_eval_terrier, pyjnius, pyautocorpus, patsy, nptyping, more_itertools, matchpy, lz4, lxml, dill, cwl-eval, chest, ir_measures, deprecated, beautifulsoup4, statsmodels, ir_datasets, python-terrier
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed beautifulsoup4-4.12.0 cbor-1.0.0 chest-0.2.3 cwl-eval-1.0.12 deprecated-1.2.13 dill-0.3.6 heapdict-1.0.1 ijson-3.2.0.post0 ir_datasets-0.5.4 ir_measures-0.3.1 lxml-4.9.2 lz4-4.3.2 matchpy-0.5.5 more_itertools-9.1.0 multiset-2.1.1 nptyping-1.4.4 patsy-0.5.3 pyautocorpus-0.1.9 pyjnius-1.4.2 python-terrier-0.9.2 pytrec_eval_terrier-0.5.5 soupsieve-2.4 statsmodels-0.13.5 trec-car-tools-2.6 typish-1.9.3 unlzw3-0.2.2 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wget-3.2 wrapt-1.15.0 zlib-state-0.1.5
# terrier-assemblies 5.7 jar-with-dependencies not found, downloading to /Users/souleymbaye/.pyterrier...
# Done
# terrier-python-helper 0.0.7 jar not found, downloading to /Users/souleymbaye/.pyterrier...
# Done
# terrier-prf -SNAPSHOT jar not found, downloading to /Users/souleymbaye/.pyterrier...
# Done
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.

# %% [markdown]
# ## Indexation d'une collection
#
# Il est possible d'indexer plusieurs formats de collection : format TREC, fichiers en texte brut ou en PDF, ou encore des Dataframe Pandas ([pour plus de détails](https://pyterrier.readthedocs.io/en/latest/terrier-indexing.html)).
#
# Un petit exemple à titre illustratif est foourni dans le code suivant :

# %%
import pandas as pd

# configuration de l'affichage
pd.set_option('display.max_colwidth', 150)

# le jeu de données au format DataFrame
docs_df = pd.DataFrame([
        ["d1", "this is the first document of many documents"],
        ["d2", "this is another document"],
        ["d3", "the topic of this document is unknown"]
    ], columns=["docno", "text"])

# création de l'index
indexer = pt.DFIndexer("./index_3docs", overwrite=True)         # Définition du format de données (DFIndexer())
index_ref = indexer.index(docs_df["text"], docs_df["docno"])    # Indexation des champs text et docno
# !ls -lh index_3docs/                                            # Affichage de l'index sauvegardé dans "./index_3docs/"
# Out:
# total 36K
# -rw-r--r-- 1 root root    3 Jun 17 11:51 data.direct.bf
# -rw-r--r-- 1 root root   51 Jun 17 11:51 data.document.fsarrayfile
# -rw-r--r-- 1 root root    4 Jun 17 11:51 data.inverted.bf
# -rw-r--r-- 1 root root  344 Jun 17 11:51 data.lexicon.fsomapfile
# -rw-r--r-- 1 root root  249 Jun 17 11:51 data.lexicon.fsomaphash
# -rw-r--r-- 1 root root   24 Jun 17 11:51 data.meta.idx
# -rw-r--r-- 1 root root   48 Jun 17 11:51 data.meta.zdata
# -rw-r--r-- 1 root root 4.1K Jun 17 11:51 data.properties

# %% [markdown]
# De nombreux fichiers sont créés : index direct, index inverse, méta-données de l'index et de la configuration de l'indexation, etc...
#
#
# Il est également possible de modifier la configuration de l'indexation : [voir ici](https://pyterrier.readthedocs.io/en/latest/terrier-indexing.html#indexing-configuration).
#
# Pour chager un index existant en local :

# %%
index = pt.IndexFactory.of(index_ref)

# %% [markdown]
# Il est aussi possible de voir les statistiques de l'index.
# pour connaître toutes les fonctions d'interrogation, se référencer à la [javadoc](http://terrier.org/docs/current/javadoc/org/terrier/structures/Index.html).

# %%
# statistiques de la collection
print(index.getCollectionStatistics().toString())

# %%
# statistiques du vocabulaire.
# Nt : document frequency : nombre de documents contenant le terme
# TF : term frequency : nombre d'occurences du terme
# maxTF : nombre d'occurences maximal pour un document
for kv in index.getLexicon():
  print("%s (%s) -> %s (%s)" % (kv.getKey(), type(kv.getKey()), kv.getValue().toString(), type(kv.getValue()) ) )

# %%
# focus sur un terme particulier
index.getLexicon()["document"].toString()

# %%
# récupère les statistiques de l'index inverse à partir d'un terme particulier
pointer = index.getLexicon()["document"]
for posting in index.getInvertedIndex().getPostings(pointer):
    print(posting.toString() + " doclen=%d" % posting.getDocumentLength())

# %% [markdown]
# De plus, PyTerrier met à disposition [une collection de jeux de données pré-traités](https://pyterrier.readthedocs.io/en/latest/datasets.html).
# Dans ce qui suit, nous allons nous concentrer sur le jeu de données CORD19 qui recense des articles liés à la crise sanitaire Covid-19. Il est

# %%
import os

cord19 = pt.datasets.get_dataset('irds:cord19/trec-covid')
pt_index_path = './terrier_cord19'

if not os.path.exists(pt_index_path + "/data.properties"):
  # création de l'index. Utilisation de l'itérateur pour parcourir la collection
  indexer = pt.index.IterDictIndexer(pt_index_path)

  # on donne à l'index la fonction pour parcourir l'index avec l'itérateur  get_corpus_iter() 
  # On spécifie les champs à indexer et les meta-données à sauvegarder
  index_ref = indexer.index(cord19.get_corpus_iter(), 
                            fields=('abstract',), 
                            meta=('docno',))

else:
  # dans le cas où l'index existe déjà
  index_ref = pt.IndexRef.of(pt_index_path + "/data.properties")
index = pt.IndexFactory.of(index_ref)

# %% [markdown]
# **Exercice 1**
#
# Afficher les statistiques de l'index Cord19 et analyser statistiques du terme "tv" (pas trop fréquent pour question d'affichage).

# %% [markdown]
# ## Recherche de documents à partir de l'index
#
# Pour effectuer une recherche dans l'index, il faut utiliser la fonction batchRetrieve qui prend en paramètre l'index et le modèle de pondération (tf, tf-idf, etc...). La liste des modèles supportés est disponible [ici](http://terrier.org/docs/current/javadoc/org/terrier/matching/models/package-summary.html).

# %%
br = pt.BatchRetrieve(index, wmodel="Tf")
br.search("chemical reactions")

# %% [markdown]
# On récupère alors un DataFrame dont les colonnes sont les suivantes :
# *   qid : identifiant de la requête. Par défaut, il s'agit de "1", puisqu'il s'agit de notre première et unique requête.
# *   docid : l'identifiant interne de Terrier pour chaque document
# *   docno : l'identifiant unique externe (chaîne de caractères) pour chaque document
# *   score : score des documents selon le modèle choisi (ici : fréquence totale des tf des termes de la requête dans chaque document)
# *   rank : rang du document dénotant l'ordre décroissant par score.
# *   query : la requête d'entrée

# %%
# autre exemple de modèle : TF-IDF
tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
tfidf.search("chemical reactions")

# %% [markdown]
# On peut aussi fournir plusieurs requêtes grâce à un dataFrame. Pour interroger l'index, on applique la fonction transform() au BatchRetriever (br).
# pour plus de détails, voir [les propriétés des transformations](https://pyterrier.readthedocs.io/en/latest/transformer.html) ainsi que les [opérations possibles](https://pyterrier.readthedocs.io/en/latest/operators.html).

# %%
import pandas as pd
queries = pd.DataFrame([["q1", "document"], ["q2", "first document"]], columns=["qid", "query"])
br.transform(queries)       # ou aussi : br(queries)

# %% [markdown]
# **Exercice 2**
#
# Ordonnancer les documents pour 3 requêtes : "covid disease", "hospital" et "home".
# La fonction d'ordonnacement devra être de la forme suivante :
#
#
# ```
# 0.4 * score_Bm25 + 0.6 * score_Dirichlet
# ```

# %% [markdown]
# **Excercice 3**
#
# Créez un ordonnanceur qui effectue les opérations suivantes :
# * obtient les 10 documents les mieux notés par fréquence de terme (wmodel="Tf")
# * obtenir les 10 documents les mieux notés par TF.IDF (wmodel="TF_IDF")
# * ré-ordonne uniquement les documents trouvés dans les DEUX paramètres de recherche précédents en utilisant BM25.
#
# Combien de documents sont récupérés par ce pipeline complet pour la requête "chemical"?
#
# Vérification : le document avec le docno "37771" devrait avoir un score de 12.426309 $ pour la requête "chemical".

# %% [markdown]
# ## Reformulation de requêtes
#
# Il est également possible de mettre en place des pipelines de [reformulation de requêtes](https://pyterrier.readthedocs.io/en/latest/rewrite.html).

# %%
bo1 = pt.rewrite.Bo1QueryExpansion(index)
dph = pt.BatchRetrieve(index, wmodel="DPH")
pipeline = dph >> bo1 >> dph
pipeline.search("chemical reactions")

# %% [markdown]
# L'autre solution est de l'intégrer directement dans la fonction d'ordonnancement. Mais la requête reformulée n'est pas visible et la solution précédente fait prendre conscience de la pipeline faite par le système de RI (ranking >> reformulation >> ranking quand on utilise des modèles basés sur la relevance feedback. ou reformulation >> ranking sinon). Plus d'exemples [ici](https://pyterrier.readthedocs.io/en/latest/rewrite.html).

# %%
# modèle DPH avant reformulation de requête
pipelineQE = pt.BatchRetrieve(index, wmodel="DPH", controls={"qemodel" : "Bo1", "qe" : "off"})
pipelineQE.search("chemical reactions")

# %%
# modèle DPH après reformulation de requête
pipelineQE = pt.BatchRetrieve(index, wmodel="DPH", controls={"qemodel" : "Bo1", "qe" : "on"})
pipelineQE.search("chemical reactions")

# %% [markdown]
# ### Evaluation d'un système de recherche d'information
#
# Pour évaluer un système de RI, il est nécessaire d'avoir un jeu de données constitué de requêtes et de jugements de pertinence.

# %%
# exemple de 5 requêtes pour cord19
cord19.get_topics(variant='title').head(5)

# %%
# exemple de jugements de pertinence pour les 5 premières requêtes
cord19.get_qrels().head(5)

# %% [markdown]
# **Exercice 4**
#
# A partir des requêtes et des jugements de pertinence du jeu de données CORD19, Ecrire le code qui permet d'afficher les résultats de la première requête de Cord19. L'affichage fusionnera les colonnes retournées par le BatchRetriever et les colonnes des qrels (merge sur qid et docno pour rajouter label et iteration au tableau).

# %% [markdown]
# Il existe cependant une fonction qui permet de calculer l'efficacité de ces ordonnancements au travers des métriques d'évaluation (map, précision, rappel, ndcg, ...)

# %%
pt.Experiment(
    [tfidf],
    cord19.get_topics(variant='title'),
    cord19.get_qrels(),
    eval_metrics=["map", "ndcg"])
# Out:
#          name       map      ndcg
# 0  BR(TF_IDF)  0.180008  0.370795

# %% [markdown]
# **Exercice 5**
#
# Réaliser une expérience comparant l'expansion de requêtes avec le modèle Bo1 et basé sur la KL-divergence; L'expérience est réalisée sur TREC CORD19 avec le modèle de référence BM25. Vous devrez construire des pipelines appropriées (plus de détails sur [l'expansion](https://pyterrier.readthedocs.io/en/latest/rewrite.html) et les [expérimentations](https://pyterrier.readthedocs.io/en/latest/experiments.html)).
#
# Quelles approches entraînent des augmentations significatives de NDCG et MAP ou autres métriques ?
